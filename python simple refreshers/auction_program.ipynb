# %%
! pip install replit
! pip install art

from replit import clear

from art import logo

print(logo)

bids = {}
bidding_finished = False

def find_highest_bidder(bidding_record):
  highest_bid = 0
  winner = ""
  # bidding_record = {"Angela": 123, "James": 321}
  for bidder in bidding_record:
    bid_amount = bidding_record[bidder]
    if bid_amount > highest_bid: 
      highest_bid = bid_amount
      winner = bidder
  print(f"The winner is {winner} with a bid of ${highest_bid}")

while not bidding_finished:
  name = input("What is your name?: ")
  price = int(input("What is your bid?: $"))
  bids[name] = price
  should_continue = input("Are there any other bidders? Type 'yes or 'no'.\n")
  if should_continue == "no":
    bidding_finished = True
    find_highest_bidder(bids)
  elif should_continue == "yes":
    clear()
# Out:
# Requirement already satisfied: replit in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (3.6.3)
# Requirement already satisfied: Flask>=2.0.0 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (3.0.3)
# Requirement already satisfied: Werkzeug<4,>=2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (3.0.3)
# Requirement already satisfied: aiohttp>=3.6.2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (3.9.5)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.8.3 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (2.8.3)
# Requirement already satisfied: protobuf<5.0.0,>=4.21.8 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (4.25.3)
# Requirement already satisfied: pyseto<2.0.0,>=1.6.11 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (1.7.8)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (2.31.0)
# Requirement already satisfied: typing_extensions<5,>=4 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (4.11.0)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from replit) (2.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from aiohttp>=3.6.2->replit) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from aiohttp>=3.6.2->replit) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from aiohttp>=3.6.2->replit) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from aiohttp>=3.6.2->replit) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from aiohttp>=3.6.2->replit) (1.9.4)
# Requirement already satisfied: Jinja2>=3.1.2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from Flask>=2.0.0->replit) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from Flask>=2.0.0->replit) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from Flask>=2.0.0->replit) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from Flask>=2.0.0->replit) (1.8.2)
# Requirement already satisfied: argon2-cffi>=23.1.0 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from pyseto<2.0.0,>=1.6.11->replit) (23.1.0)
# Requirement already satisfied: cryptography<43,>=42.0.1 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from pyseto<2.0.0,>=1.6.11->replit) (42.0.7)
# Requirement already satisfied: iso8601<3.0.0,>=1.0.2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from pyseto<2.0.0,>=1.6.11->replit) (2.1.0)
# Requirement already satisfied: pycryptodomex>=3.18.0 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from pyseto<2.0.0,>=1.6.11->replit) (3.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from requests<3.0.0,>=2.25.1->replit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from requests<3.0.0,>=2.25.1->replit) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from requests<3.0.0,>=2.25.1->replit) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from Werkzeug<4,>=2->replit) (2.1.5)
# Requirement already satisfied: argon2-cffi-bindings in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from argon2-cffi>=23.1.0->pyseto<2.0.0,>=1.6.11->replit) (21.2.0)
# Requirement already satisfied: colorama in c:\users\meddieek\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask>=2.0.0->replit) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from cryptography<43,>=42.0.1->pyseto<2.0.0,>=1.6.11->replit) (1.16.0)
# Requirement already satisfied: pycparser in d:\projects\personal projects\personal_projects\personal_projects\.conda\lib\site-packages (from cffi>=1.12->cryptography<43,>=42.0.1->pyseto<2.0.0,>=1.6.11->replit) (2.22)
# Collecting art
#   Downloading art-6.2-py3-none-any.whl.metadata (69 kB)
#      ---------------------------------------- 0.0/69.2 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/69.2 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/69.2 kB ? eta -:--:--
#      ----------- -------------------------- 20.5/69.2 kB 108.9 kB/s eta 0:00:01
#      ----------- -------------------------- 20.5/69.2 kB 108.9 kB/s eta 0:00:01
#      ----------- -------------------------- 20.5/69.2 kB 108.9 kB/s eta 0:00:01
#      ---------------- --------------------- 30.7/69.2 kB 108.9 kB/s eta 0:00:01
#      ---------------------- --------------- 41.0/69.2 kB 140.3 kB/s eta 0:00:01
#      --------------------------------- ---- 61.4/69.2 kB 172.4 kB/s eta 0:00:01
#      -------------------------------------- 69.2/69.2 kB 188.3 kB/s eta 0:00:00
# Downloading art-6.2-py3-none-any.whl (601 kB)
#    ---------------------------------------- 0.0/601.8 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/601.8 kB 960.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 71.7/601.8 kB 975.2 kB/s eta 0:00:01
#    ---- ---------------------------------- 71.7/601.8 kB 975.2 kB/s eta 0:00:01
#    ----- --------------------------------- 92.2/601.8 kB 581.0 kB/s eta 0:00:01
#    --------- ---------------------------- 153.6/601.8 kB 762.6 kB/s eta 0:00:01
#    ------------ ------------------------- 204.8/601.8 kB 888.4 kB/s eta 0:00:01
#    ------------ ------------------------- 204.8/601.8 kB 888.4 kB/s eta 0:00:01
#    -------------- ----------------------- 225.3/601.8 kB 724.0 kB/s eta 0:00:01
#    --------------------- ---------------- 337.9/601.8 kB 952.6 kB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/601.8 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/601.8 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/601.8 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/601.8 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/601.8 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/601.8 kB 1.2 MB/s eta 0:00:01
#    ------------------------------------ - 583.7/601.8 kB 965.4 kB/s eta 0:00:01
#    ------------------------------------ - 583.7/601.8 kB 965.4 kB/s eta 0:00:01
#    ------------------------------------ - 583.7/601.8 kB 965.4 kB/s eta 0:00:01
#    ------------------------------------ - 583.7/601.8 kB 965.4 kB/s eta 0:00:01
#    -------------------------------------- 601.8/601.8 kB 788.8 kB/s eta 0:00:00
# Installing collected packages: art
# Successfully installed art-6.2
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       2 get_ipython().system(' pip install art')
#       4 from replit import clear
# ----> 6 from art import logo
#       8 print(logo)
#      10 bids = {}
#
# ImportError: cannot import name 'logo' from 'art' (d:\PROJECTS\Personal Projects\personal_projects\personal_projects\.conda\Lib\site-packages\art\__init__.py)
